# %% [markdown]
# # Get and Clean a .csv

# %% [markdown]
# Now, let's put on our Fedora's and get to Exploring. In this project, we use Pandas dataframe in Python to clean, explore, summarize, and visualize world bank CO2 emission data.
#
# **Dataset:** [Download](http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/)
#
# **Source:** The World Bank Data
#
# **Tools/Platform:** ipython notebook (Lates versions of python and Anaconda) (default, Feb. 2, 2021)
#
# **Presentation Outline:**
#
# * Find and set working directory
# * Get the Data
# * Import the data using Pandas
# * Dataframe characteristics
# * Subset the Dataframe
# * Conditional Subsetting
# * Data Cleaning
# * For next time...
# * Data Exploration : Exploring data through scatter plots, histograms, bar graphs
# * Creating an interactive searchable widget

# %%
# Install Libraries we need, in this case is only pandas
import pandas as pd

# %% [markdown]
# ## Set or Change Working Directory

# %%
# First we have to import the os library to specify to python our computer directory. 
import os
 
# The path for listing items
path = '.'
 
# The list of items
files = os.listdir(path)
 
# Loop to print each filename separately
for filename in files:
    print(filename)
# Out:
# .DS_Store
# Lecture2.ipynb
# Water Data.ipynb
# Working with yfinance.ipynb
# emissions.csv
# emissions_clean.csv
# Lecture 2.ipynb
# meta.csv
# .ipynb_checkpoints

# %%
#Now we give python a path to specific folder.
import sys
import os
sys.path.append(r'C:/Documents/Python&Finance/Lecture 2')

# %%
path = os.getcwd()

print(path)
# Out:
# /Users/kurtsemm/Documents/Python&Finance/Lecture 2

# %% [markdown]
# ### To change working directory just insert the correct folder path name into:
#
# os.chdir('file path to folder')
#
# print(os.getcwd())
#
# * For Mac users only use one "/"
# * For Windows/pc users use two "//"

# %% [markdown]
# # Importing .csv file

# %%
#Read the csv file. 
df = pd.read_csv('emissions.csv', skiprows=4)

# %% [markdown]
# ## Dataframe characteristics

# %%
df.head()
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  EN.ATM.CO2E.PC  204.620372  208.822811  226.118079  214.800370  207.615777
# 1  EN.ATM.CO2E.PC    0.046057    0.053589    0.073721    0.074161    0.086174
# 2  EN.ATM.CO2E.PC    0.100835    0.082204    0.210531    0.202737    0.213560
# 3  EN.ATM.CO2E.PC    1.258195    1.374186    1.439956    1.181681    1.111742
# 4  EN.ATM.CO2E.PC         NaN         NaN         NaN         NaN         NaN
#
#          1965  ...       2012      2013      2014      2015      2016  2017  \
# ...

# %%
df.head(6)
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
# 5   Arab World          ARB  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  EN.ATM.CO2E.PC  204.620372  208.822811  226.118079  214.800370  207.615777
# 1  EN.ATM.CO2E.PC    0.046057    0.053589    0.073721    0.074161    0.086174
# 2  EN.ATM.CO2E.PC    0.100835    0.082204    0.210531    0.202737    0.213560
# 3  EN.ATM.CO2E.PC    1.258195    1.374186    1.439956    1.181681    1.111742
# 4  EN.ATM.CO2E.PC         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.head(n=6)
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
# 5   Arab World          ARB  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  EN.ATM.CO2E.PC  204.620372  208.822811  226.118079  214.800370  207.615777
# 1  EN.ATM.CO2E.PC    0.046057    0.053589    0.073721    0.074161    0.086174
# 2  EN.ATM.CO2E.PC    0.100835    0.082204    0.210531    0.202737    0.213560
# 3  EN.ATM.CO2E.PC    1.258195    1.374186    1.439956    1.181681    1.111742
# 4  EN.ATM.CO2E.PC         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.tail(7)
# Out:
#      Country Name Country Code                          Indicator Name  \
# 257         World          WLD  CO2 emissions (metric tons per capita)
# 258         Samoa          WSM  CO2 emissions (metric tons per capita)
# 259        Kosovo          XKX  CO2 emissions (metric tons per capita)
# 260   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 261  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 262        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 263      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#      Indicator Code      1960      1961      1962      1963      1964  \
# 257  EN.ATM.CO2E.PC  0.003108  0.003079  0.003151  0.003256  0.003373
# 258  EN.ATM.CO2E.PC  0.135028  0.163552  0.158366  0.184026  0.208112
# 259  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN
# 260  EN.ATM.CO2E.PC  0.011038  0.013599  0.012729  0.014518  0.017550
# ...

# %%
#Gives you dimensions of your dataset.
df.shape
# Out:
# (264, 66)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65'],
#       dtype='object')

# %%
df.columns[1]
# Out:
# 'Country Code'

# %%
df.columns[[0,1]]
# Out:
# Index(['Country Name', 'Country Code'], dtype='object')

# %% [markdown]
# ## Subset the Dataframe

# %%
df['Country Name']
# Out:
# 0             Aruba
# 1       Afghanistan
# 2            Angola
# 3           Albania
# 4           Andorra
#            ...
# 259          Kosovo
# 260     Yemen, Rep.
# 261    South Africa
# 262          Zambia
# 263        Zimbabwe
# Name: Country Name, Length: 264, dtype: object

# %%
df[df.columns[0]]
# Out:
# 0             Aruba
# 1       Afghanistan
# 2            Angola
# 3           Albania
# 4           Andorra
#            ...
# 259          Kosovo
# 260     Yemen, Rep.
# 261    South Africa
# 262          Zambia
# 263        Zimbabwe
# Name: Country Name, Length: 264, dtype: object

# %%
df[df.columns[-1]]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 259   NaN
# 260   NaN
# 261   NaN
# 262   NaN
# 263   NaN
# Name: Unnamed: 65, Length: 264, dtype: float64

# %%
df[['Country Name','Country Code']]
# Out:
#      Country Name Country Code
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
# [264 rows x 2 columns]

# %%
df[0:3]
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  EN.ATM.CO2E.PC  204.620372  208.822811  226.118079  214.800370  207.615777
# 1  EN.ATM.CO2E.PC    0.046057    0.053589    0.073721    0.074161    0.086174
# 2  EN.ATM.CO2E.PC    0.100835    0.082204    0.210531    0.202737    0.213560
#
#          1965  ...       2012      2013      2014      2015      2016  2017  \
# 0  185.203957  ...  13.157722  8.353561  8.410064  8.610374  8.426911   NaN
# 1    0.101285  ...   0.345149  0.280455  0.253728  0.262556  0.245101   NaN
# 2    0.205891  ...   1.361181  1.295075  1.664741  1.240245  1.202861   NaN
#
#    2018  2019  2020  Unnamed: 65
# 0   NaN   NaN   NaN          NaN
# ...

# %% [markdown]
# ## Condtional Subsetting

# %%
#Data where the country name is Canada, Returns True/False
df['Country Name']=='USA'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# Name: Country Name, Length: 264, dtype: bool

# %%
df[df['Country Name']=='World']
# Out:
#     Country Name Country Code                          Indicator Name  \
# 257        World          WLD  CO2 emissions (metric tons per capita)
#
#      Indicator Code      1960      1961      1962      1963      1964  \
# 257  EN.ATM.CO2E.PC  0.003108  0.003079  0.003151  0.003256  0.003373
#
#          1965  ...      2012      2013      2014      2015      2016  2017  \
# 257  0.003454  ...  0.004983  0.004986  0.004941  0.004902  0.004849   NaN
#
#      2018  2019  2020  Unnamed: 65
# 257   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %%
df[df['Country Code']=='OSS']
# Out:
#            Country Name Country Code                          Indicator Name  \
# 181  Other small states          OSS  CO2 emissions (metric tons per capita)
#
#      Indicator Code      1960      1961      1962      1963      1964  \
# 181  EN.ATM.CO2E.PC  0.627724  0.768731  0.770504  1.612134  1.712589
#
#          1965  ...      2012      2013      2014      2015      2016  2017  \
# 181  1.679834  ...  7.196496  6.874011  7.599435  7.257408  7.041731   NaN
#
#      2018  2019  2020  Unnamed: 65
# 181   NaN   NaN   NaN          NaN
#
# [1 rows x 66 columns]

# %% [markdown]
# ## Subset the Dataframe

# %%
#Show Error
df[(df['Country Name'] == 'United States') | (df['Country Code'] == 'DEU')]
# Out:
#       Country Name Country Code                          Indicator Name  \
# 53         Germany          DEU  CO2 emissions (metric tons per capita)
# 249  United States          USA  CO2 emissions (metric tons per capita)
#
#      Indicator Code       1960       1961       1962       1963       1964  \
# 53   EN.ATM.CO2E.PC        NaN        NaN        NaN        NaN        NaN
# 249  EN.ATM.CO2E.PC  15.999779  15.681256  16.013937  16.482762  16.968119
#
#           1965  ...       2012       2013       2014       2015       2016  \
# 53         NaN  ...   9.177916   9.398672   8.895302   8.900419   8.840129
# 249  17.451725  ...  16.193429  16.362224  16.416576  15.989866  15.502204
#
#      2017  2018  2019  2020  Unnamed: 65
# 53    NaN   NaN   NaN   NaN          NaN
# 249   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 66 columns]

# %%
df[['Country Name','Country Code','1984']][54:75]
# Out:
#                                      Country Name Country Code       1984
# 54                                       Djibouti          DJI   0.867038
# 55                                       Dominica          DMA   0.595848
# 56                                        Denmark          DNK   9.950133
# 57                             Dominican Republic          DOM   1.175661
# 58                                        Algeria          DZA   3.267070
# 59    East Asia & Pacific (excluding high income)          EAP   1.521033
# 60                     Early-demographic dividend          EAR   1.268029
# 61                            East Asia & Pacific          EAS   2.238889
# 62  Europe & Central Asia (excluding high income)          ECA  17.553118
# 63                          Europe & Central Asia          ECS  11.825196
# 64                                        Ecuador          ECU   2.403764
# 65                               Egypt, Arab Rep.          EGY   1.330844
# ...

# %% [markdown]
# # Let's Start Cleaning

# %%
df.loc[[93,151,181,257]]
# Out:
#                    Country Name Country Code  \
# 93                  High income          HIC
# 151  Middle East & North Africa          MEA
# 181          Other small states          OSS
# 257                       World          WLD
#
#                              Indicator Name  Indicator Code      1960  \
# 93   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  7.413876
# 151  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.938534
# 181  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.627724
# 257  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.003108
#
#          1961      1962      1963      1964      1965  ...       2012  \
# 93   7.467719  7.724616  8.057745  8.363214  8.633775  ...  10.965684
# 151  0.971387  1.032458  1.167236  1.319993  1.530650  ...   6.252016
# 181  0.768731  0.770504  1.612134  1.712589  1.679834  ...   7.196496
# 257  0.003079  0.003151  0.003256  0.003373  0.003454  ...   0.004983
#
# ...

# %% [markdown]
# ## Problems with the data:
#
# 1. Some rows are aggregates of countries rather than actual countries (e.g., "World").
# 2. Some columns are irrelevant and can be removed (e.g., "Indicator Name").
# 3. Some years have no data for any country (e.g., 2017 to 2020).

# %% [markdown]
# ### We want to clean the Data, Where do we start?
# 1. Some rows are aggregates of countries rather than actual countries (e.g., "World").
#
#
# ### Goals:
# * Remove rows that do not contain an actual country. Fortunately, the World Bank provides us with metadata on which rows are countries and which are aggregates.**
# * import countries_metadata.csv
# * merge metadata with data on Country Code

# %%
meta = pd.read_csv('meta.csv', encoding = "utf-8")
meta.head(10)
# Out:
#   Country Code                      Region          IncomeGroup  \
# 0          ABW   Latin America & Caribbean          High income
# 1          AFG                  South Asia           Low income
# 2          AGO          Sub-Saharan Africa  Lower middle income
# 3          ALB       Europe & Central Asia  Upper middle income
# 4          AND       Europe & Central Asia          High income
# 5          ARB                         NaN                  NaN
# 6          ARE  Middle East & North Africa          High income
# 7          ARG   Latin America & Caribbean  Upper middle income
# 8          ARM       Europe & Central Asia  Upper middle income
# 9          ASM         East Asia & Pacific  Upper middle income
#
#                                         SpecialNotes             TableName  \
# 0                                                NaN                 Aruba
# 1                                                NaN           Afghanistan
# ...

# %%
merge = pd.merge(df,meta, on = 'Country Code')
merge.shape
# Out:
# (263, 71)

# %%
merge.head(10)
# Out:
#            Country Name Country Code                          Indicator Name  \
# 0                 Aruba          ABW  CO2 emissions (metric tons per capita)
# 1           Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2                Angola          AGO  CO2 emissions (metric tons per capita)
# 3               Albania          ALB  CO2 emissions (metric tons per capita)
# 4               Andorra          AND  CO2 emissions (metric tons per capita)
# 5            Arab World          ARB  CO2 emissions (metric tons per capita)
# 6  United Arab Emirates          ARE  CO2 emissions (metric tons per capita)
# 7             Argentina          ARG  CO2 emissions (metric tons per capita)
# 8               Armenia          ARM  CO2 emissions (metric tons per capita)
# 9        American Samoa          ASM  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# ...

# %%
merge = merge[pd.notnull(merge['Region'])]

# %%
merge.head(2)
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  EN.ATM.CO2E.PC  204.620372  208.822811  226.118079  214.800370  207.615777
# 1  EN.ATM.CO2E.PC    0.046057    0.053589    0.073721    0.074161    0.086174
#
#          1965  ...  2017  2018  2019  2020  Unnamed: 65  \
# 0  185.203957  ...   NaN   NaN   NaN   NaN          NaN
# 1    0.101285  ...   NaN   NaN   NaN   NaN          NaN
#
#                       Region  IncomeGroup  SpecialNotes    TableName  \
# 0  Latin America & Caribbean  High income           NaN        Aruba
# 1                 South Asia   Low income           NaN  Afghanistan
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
#
# [2 rows x 71 columns]

# %%
merge.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65',
#        'Region', 'IncomeGroup', 'SpecialNotes', 'TableName', 'Unnamed: 5'],
#       dtype='object')

# %%
merge = merge.drop('Indicator Name', 1)
merge = merge.drop('Indicator Code', 1)

# %%
merge.count()
# Out:
# Country Name    217
# Country Code    217
# 1960            156
# 1961            157
# 1962            159
#                ...
# Region          217
# IncomeGroup     217
# SpecialNotes     58
# TableName       217
# Unnamed: 5        0
# Length: 69, dtype: int64

# %%
merge['2017']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 258   NaN
# 259   NaN
# 260   NaN
# 261   NaN
# 262   NaN
# Name: 2017, Length: 217, dtype: float64

# %%
merge = merge.drop(['2017','2018','2019','2020', 'TableName', 'Unnamed: 5'], 1)

# %%
merge.count()
# Out:
# Country Name    217
# Country Code    217
# 1960            156
# 1961            157
# 1962            159
#                ...
# 2016            202
# Unnamed: 65       0
# Region          217
# IncomeGroup     217
# SpecialNotes     58
# Length: 63, dtype: int64

# %%
merge.mean(axis=1)
# Out:
# 0      104.730601
# 1        0.148050
# 2        0.651715
# 3        1.651686
# 4        6.824624
#           ...
# 258      4.545618
# 259      0.448771
# 260      8.187400
# 261      0.478680
# 262      1.195755
# Length: 217, dtype: float64

# %%
merge=merge[pd.notnull(merge.mean(axis=1))]
merge.head(10)
# Out:
#             Country Name Country Code        1960        1961        1962  \
# 0                  Aruba          ABW  204.620372  208.822811  226.118079
# 1            Afghanistan          AFG    0.046057    0.053589    0.073721
# 2                 Angola          AGO    0.100835    0.082204    0.210531
# 3                Albania          ALB    1.258195    1.374186    1.439956
# 4                Andorra          AND         NaN         NaN         NaN
# 6   United Arab Emirates          ARE    0.119035    0.109141    0.163533
# 7              Argentina          ARG    2.383343    2.458551    2.538446
# 8                Armenia          ARM         NaN         NaN         NaN
# 10   Antigua and Barbuda          ATG    0.677431    0.866730    1.838721
# 11             Australia          AUS    8.582937    8.641569    8.835688
#
#           1963        1964        1965        1966        1967  ...  \
# 0   214.800370  207.615777  185.203957  172.119951  210.779072  ...
# ...

# %%
dfc = merge
dfc.head(10)
# Out:
#             Country Name Country Code        1960        1961        1962  \
# 0                  Aruba          ABW  204.620372  208.822811  226.118079
# 1            Afghanistan          AFG    0.046057    0.053589    0.073721
# 2                 Angola          AGO    0.100835    0.082204    0.210531
# 3                Albania          ALB    1.258195    1.374186    1.439956
# 4                Andorra          AND         NaN         NaN         NaN
# 6   United Arab Emirates          ARE    0.119035    0.109141    0.163533
# 7              Argentina          ARG    2.383343    2.458551    2.538446
# 8                Armenia          ARM         NaN         NaN         NaN
# 10   Antigua and Barbuda          ATG    0.677431    0.866730    1.838721
# 11             Australia          AUS    8.582937    8.641569    8.835688
#
#           1963        1964        1965        1966        1967  ...  \
# 0   214.800370  207.615777  185.203957  172.119951  210.779072  ...
# ...

# %%
dfc.to_csv('emissions_clean.csv', index=False)

# %% [markdown]
# ## Who were the highest emitters by average (mean)?

# %%
dfc[['Country Name','2016']].sort_values('2016',ascending=False).head()
# Out:
#             Country Name       2016
# 197                Qatar  38.901471
# 49               Curacao  33.761462
# 239  Trinidad and Tobago  31.844851
# 124               Kuwait  24.952513
# 20               Bahrain  22.228981

# %%
dfc[['Country Name','2016']].sort_values('2016',ascending = True).head()
# Out:
#                  Country Name      2016
# 41           Congo, Dem. Rep.  0.025645
# 210                   Somalia  0.045496
# 14                    Burundi  0.047201
# 32   Central African Republic  0.065458
# 226                      Chad  0.069756

# %%
by_region = dfc.groupby('Region').agg('mean')
by_region['2014']
# Out:
# Region
# East Asia & Pacific            5.047091
# Europe & Central Asia          6.317727
# Latin America & Caribbean      5.337595
# Middle East & North Africa     9.866201
# North America                 13.878805
# South Asia                     1.127367
# Sub-Saharan Africa             1.003095
# Name: 2014, dtype: float64

# %% [markdown]
# #WILL GO OVER TEH REST IN THE NEXT CLASS

# %% [markdown]
# ## Simple bar chart

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.bar(range(len(by_region['1990'])),by_region['1990'].values)
plt.xticks(range(len(by_region['1990'])), by_region['1990'].index,rotation=70)
plt.ylabel('CO2 Emission (Metrin ton/capita)')
plt.title('Mean CO2 Emission by Region in 1990')
# Out:
# Text(0.5, 1.0, 'Mean CO2 Emission by Region in 1990')

# %%
world_x = dfc[dfc.columns[2:63]].mean().index
world_y = dfc[dfc.columns[2:63]].mean()

# Plot
plt.plot(world_x,world_y)
plt.title("CO2 Emission per capita averaged accross all countries")
plt.ylabel("Mean CO2 Emission (Metric tons/capita)")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # References
# The following code is a replica and update of the following code: [Github](https://github.com/Mzkarim/Exploring--CO2-Emission-Data-).

# %% [markdown]
# For next time...

# %%
def plot_countries(dfc):
    from pylab import rcParams
    rcParams['figure.figsize'] = (12,6)
    import numpy as np

    colormap = plt.get_cmap('gist_rainbow')
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_prop_cycle([colormap(i) for i in np.linspace(0, 0.9, len(range(1960,2012)))])


    for i in range(0,len(mydf)):
        plt.plot(mydf.iloc[i,][2:54])
    plt.xticks(range(len(range(1960,2012))),dfc.columns.values[2:54], rotation = 70)
    #plt.legend(dfc["Country Name"].values, loc='upper left')
    plt.legend(dfc["Country Name"].values, ncol=4, loc='upper center', 
               bbox_to_anchor=[0.4, -0.1], 
               columnspacing=1.0, labelspacing=0.0,
               handletextpad=0.0, handlelength=1.0,
               fancybox=True)
    plt.ylabel("CO2 Emission (metric ton/capita)")
    plt.title("CO2 Emission Per Capita by Country and Year")
    plt.show()

# %%
def filter_country(search_term):
    '''
    Filters the medals_df DataFrame to only contain rows whose Sport or Discipline
    columns contain the given search_term.
    '''
    return dfc[dfc["Country Name"].str.contains(search_term, case=False) \
                     | dfc["Country Code"].str.contains(search_term, case=False)\
                     | dfc["Region"].str.contains(search_term, case=False)]

# %%
# import display to show DataFrame content
from IPython.display import display
# import the widgets interact function to automatically create interactive UI
from IPython.html.widgets import interact

# decorate the search_and_plot_medals function using interact
# to create text field UI for search term
@interact(search='')
def search_and_plot_countries(search):
    '''
    Display medals by country when given a search term.
    '''
    filtered_country = filter_country(search)
    if len(filtered_country) == 0:
        print('No hits')
        return
    
    # show plot 
    plot_countries(filtered_country)
    # output results
    display(filtered_country)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/interaction.py in update(self, *args)
#     254                     value = widget.get_interact_value()
#     255                     self.kwargs[widget._kwarg] = value
# --> 256                 self.result = self.f(**self.kwargs)
#     257                 show_inline_matplotlib_plots()
#     258                 if self.auto_display and self.result is not None:
#
# <ipython-input-80-3063046aa13c> in search_and_plot_countries(search)
#      17
#      18     # show plot
# ---> 19     plot_countries(filtered_country)
#      20     # output results
#      21     display(filtered_country)
#
# <ipython-input-78-a81a74bb0712> in plot_countries(dfc)
#       7     fig = plt.figure()
#       8     ax = fig.add_subplot(111)
# ...
